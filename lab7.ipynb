# %%
from nltk.corpus import wordnet

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# True

# %%
word="active"
synonyms=set()
antonyms=set()
for syn in wordnet.synsets(word):
    for lemma in syn.lemmas():
        synonyms.add(lemma.name())
        if lemma.antonyms():
            for ant in lemma.antonyms():
                antonyms.add (ant.name())S

# %%
print("Synonyms of '{}':".format(word), synonyms)
print("Antonyms of '{}':".format(word), antonyms)
# Out:
# Synonyms of 'active': {'active_agent', 'dynamic', 'participating', 'active', 'active_voice', 'fighting', 'combat-ready', 'alive'}
# Antonyms of 'active': {'extinct', 'inactive', 'passive', 'stative', 'passive_voice', 'dormant', 'quiet'}
